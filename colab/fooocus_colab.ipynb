# %% [markdown]
# # MySketch — Fooocus Colab
#
# Скачай оригинальный ноутбук отсюда:
# https://colab.research.google.com/github/lllyasviel/Fooocus/blob/main/fooocus_colab.ipynb
#
# **Важно:** В конце ноутбука замени вызов launch() на:
# ```python
# from fooocus.api import Launcher
# Launcher.launch(api=True, share=True)
# ```
# Это включит API-режим и создаст публичный URL для подключения прокси.
